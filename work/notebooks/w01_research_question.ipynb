# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hassanmustafa119/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# **Why:**
#
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying webpages that should be reviewed and updated first. From the starter notebooks, I learned that features such as impressions, CTR, average position, and content age provide useful signals about page performance. My goal is to use these signals to build an evidence-based ranking that helps content teams prioritize which pages to refresh instead of relying only on manual judgment.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The Question
#
# **Research Question:**
# Can we identify webpages that should be refreshed based on their search performance and content-related features?
#
# **Decision:**
# The project helps decide which webpages should be updated first.
#
# **Action:**
# A content or SEO team can review and refresh the highest-ranked pages to improve their search performance.
#
# **Cost of a Wrong Recommendation:**
# If a page is incorrectly recommended for refresh, time and resources may be spent updating a page that does not need changes. If an important page is missed, it may continue to lose traffic and search visibility.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import subprocess
import pandas as pd

REPO_URL = "https://github.com/hassanmustafa119/flyrank-ml-internship"

if not os.path.exists("flyrank-ml-internship"):
    subprocess.run(["git", "clone", REPO_URL], check=True)

os.chdir("flyrank-ml-internship")

print("Current folder:", os.getcwd())


df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Pages with declining trend:", (df["trend_direction"] == "down").sum())
# Out:
# Current folder: /content/flyrank-ml-internship/flyrank-ml-internship
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 webpages**.
#
# The average click-through rate (CTR) is **0.5107**.
#
# Out of the 30,000 webpages, **16,262** are labeled with a **declining trend**.
#
# These numbers indicate that the dataset contains a substantial number of pages with different levels of search performance. This makes the **Refresh / Content Opportunity Scoring** lane suitable for investigating which pages should be prioritized for content updates.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project will provide **decision-support** by identifying webpages that may be good candidates for a content refresh based on observed search performance and content-related features.
#
# The results should be interpreted as **observed patterns and directional evidence**, not as proof of cause and effect.
#
# This project does **not** prove why a webpage gained or lost traffic, and it does **not** predict or explain Google's ranking algorithm. The recommendations are based only on the available dataset and should be used to support human decision-making.

# %% [markdown]
# ## Self-check
# ▶
# Before you submit, confirm each line honestly:
#
# - ✔️ Every section above is filled — markdown thinking AND the code that backs it
# - ✔️ The notebook runs top to bottom with no errors (Runtime → Run all)
# - ✔️ No client names, URLs, or private queries anywhere
# - ✔️ My claims use careful words: observed, measured, directional, decision-support
# - ✔️ Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
